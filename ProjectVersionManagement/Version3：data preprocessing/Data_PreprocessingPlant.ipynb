# %% [markdown]
# ## **Import Library**

# %%
import os
import random
import shutil
import hashlib
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import AUC, Precision, Recall
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from sklearn.metrics import confusion_matrix, classification_report, f1_score, precision_recall_curve, roc_curve, auc, precision_score, recall_score, roc_auc_score
from PIL import Image

# %% [markdown]
# # **Data Preprocessing and Data Split**

# %% [markdown]
#     Data Checking and Cleaning

# %%
def analyze_dataset(data_cleaning_path):
    datagen = ImageDataGenerator()
    data_flow = datagen.flow_from_directory(data_cleaning_path, target_size=(256, 256), class_mode='categorical')
    class_indices = data_flow.class_indices
    classes = list(class_indices.keys())
    num_classes = len(classes)
    class_counts = {}
    resolutions = []
    for class_name in classes:
        class_path = os.path.join(data_cleaning_path, class_name)
        class_counts[class_name] = 0

        for image_file in os.listdir(class_path):
            image_path = os.path.join(class_path, image_file)
            try:
                with Image.open(image_path) as img:
                    resolutions.append(img.size) 
                    class_counts[class_name] += 1
            except IOError:
                print(f"Cannot open image: {image_path}")
    resolutions = np.array(resolutions)
    unique_resolutions, counts = np.unique(resolutions, axis=0, return_counts=True)
    most_common_resolution = unique_resolutions[np.argmax(counts)]

    print("Class labels:")
    for class_name, label in class_indices.items():
        print(f" - {class_name}: {label}")

    return class_counts, most_common_resolution

def get_image_hash(image_path):
    with open(image_path, 'rb') as f:
        return hashlib.md5(f.read()).hexdigest()

def check_corrupted(image_path):
    try:
        with Image.open(image_path) as img:
            img.verify()
        return False
    except (IOError, SyntaxError):
        return True

def check_dataset(directory):
    hashes = set()
    class_counts = {}
    issues_found = False

    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if not os.path.isdir(class_path):
            continue

        class_counts[class_name] = 0

        for image_file in os.listdir(class_path):
            image_path = os.path.join(class_path, image_file)

         
            image_hash = get_image_hash(image_path)
            if image_hash in hashes:
                print(f"Duplicate image found: {image_path}")
                issues_found = True
                continue
            hashes.add(image_hash)

   
            if check_corrupted(image_path):
                print(f"Corrupted image found: {image_path}")
                issues_found = True
                continue

            class_counts[class_name] += 1
    min_count = min(class_counts.values())
    max_count = max(class_counts.values())
    if max_count > 1.5 * min_count: 
        print("Class imbalance detected.")
        issues_found = True

    return issues_found

def display_sample_images_with_info(directory, num_images=5):
    images = []
    labels = []

    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if not os.path.isdir(class_path):
            continue

        image_files = os.listdir(class_path)
        images += [os.path.join(class_path, file) for file in image_files]
        labels += [class_name for _ in image_files]

    selected_indices = random.sample(range(len(images)), num_images)
    sample_images = [images[i] for i in selected_indices]
    sample_labels = [labels[i] for i in selected_indices]

    plt.figure(figsize=(15, 3))
    for i, image_path in enumerate(sample_images):
        img = Image.open(image_path)
        plt.subplot(1, num_images, i+1)
        plt.imshow(img)
        plt.title(os.path.basename(image_path)+'\n'+f'{sample_labels[i]}\n{img.size}')
        plt.axis('off')
    
    plt.show()

data_cleaning_path = 'plantvillage dataset\color'  
class_counts, most_common_resolution = analyze_dataset(data_cleaning_path)

print("Number of samples per class:", class_counts)
print("Most common resolution:", most_common_resolution)
if not check_dataset(data_cleaning_path):
    print("No issues found in the dataset.")
display_sample_images_with_info(data_cleaning_path)
# Out:
# Found 54305 images belonging to 38 classes.
# Class labels:
#  - Apple___Apple_scab: 0
#  - Apple___Black_rot: 1
#  - Apple___Cedar_apple_rust: 2
#  - Apple___healthy: 3
#  - Blueberry___healthy: 4
#  - Cherry_(including_sour)___Powdery_mildew: 5
#  - Cherry_(including_sour)___healthy: 6
#  - Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 7
#  - Corn_(maize)___Common_rust_: 8
#  - Corn_(maize)___Northern_Leaf_Blight: 9
#  - Corn_(maize)___healthy: 10
#  - Grape___Black_rot: 11
#  - Grape___Esca_(Black_Measles): 12
#  - Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 13
#  - Grape___healthy: 14
#  - Orange___Haunglongbing_(Citrus_greening): 15
#  - Peach___Bacterial_spot: 16
#  - Peach___healthy: 17
#  - Pepper,_bell___Bacterial_spot: 18
#  - Pepper,_bell___healthy: 19
#  - Potato___Early_blight: 20
#  - Potato___Late_blight: 21
#  - Potato___healthy: 22
#  - Raspberry___healthy: 23
#  - Soybean___healthy: 24
#  - Squash___Powdery_mildew: 25
#  - Strawberry___Leaf_scorch: 26
#  - Strawberry___healthy: 27
#  - Tomato___Bacterial_spot: 28
#  - Tomato___Early_blight: 29
#  - Tomato___Late_blight: 30
#  - Tomato___Leaf_Mold: 31
#  - Tomato___Septoria_leaf_spot: 32
#  - Tomato___Spider_mites Two-spotted_spider_mite: 33
#  - Tomato___Target_Spot: 34
#  - Tomato___Tomato_Yellow_Leaf_Curl_Virus: 35
#  - Tomato___Tomato_mosaic_virus: 36
#  - Tomato___healthy: 37
# Number of samples per class: {'Apple___Apple_scab': 630, 'Apple___Black_rot': 621, 'Apple___Cedar_apple_rust': 275, 'Apple___healthy': 1645, 'Blueberry___healthy': 1502, 'Cherry_(including_sour)___Powdery_mildew': 1052, 'Cherry_(including_sour)___healthy': 854, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 513, 'Corn_(maize)___Common_rust_': 1192, 'Corn_(maize)___Northern_Leaf_Blight': 985, 'Corn_(maize)___healthy': 1162, 'Grape___Black_rot': 1180, 'Grape___Esca_(Black_Measles)': 1383, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 1076, 'Grape___healthy': 423, 'Orange___Haunglongbing_(Citrus_greening)': 5507, 'Peach___Bacterial_spot': 2297, 'Peach___healthy': 360, 'Pepper,_bell___Bacterial_spot': 997, 'Pepper,_bell___healthy': 1478, 'Potato___Early_blight': 1000, 'Potato___Late_blight': 1000, 'Potato___healthy': 152, 'Raspberry___healthy': 371, 'Soybean___healthy': 5090, 'Squash___Powdery_mildew': 1835, 'Strawberry___Leaf_scorch': 1109, 'Strawberry___healthy': 456, 'Tomato___Bacterial_spot': 2127, 'Tomato___Early_blight': 1000, 'Tomato___Late_blight': 1909, 'Tomato___Leaf_Mold': 952, 'Tomato___Septoria_leaf_spot': 1771, 'Tomato___Spider_mites Two-spotted_spider_mite': 1676, 'Tomato___Target_Spot': 1404, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 5357, 'Tomato___Tomato_mosaic_virus': 373, 'Tomato___healthy': 1591}
# Most common resolution: [256 256]
# Duplicate image found: plantvillage dataset\color\Apple___healthy\4 (1445).JPG
# Duplicate image found: plantvillage dataset\color\Apple___healthy\4 (161).JPG
# Duplicate image found: plantvillage dataset\color\Apple___healthy\4 (1629).JPG
# Duplicate image found: plantvillage dataset\color\Apple___healthy\4 (832).JPG
# Duplicate image found: plantvillage dataset\color\Apple___healthy\4 (844).JPG
# Duplicate image found: plantvillage dataset\color\Apple___healthy\4 (902).JPG
# Duplicate image found: plantvillage dataset\color\Apple___healthy\4 (906).JPG
# Duplicate image found: plantvillage dataset\color\Tomato___healthy\34c81c57-e1fa-49dd-a49d-34fe8b2385fe___GH_HL Leaf 466.1.JPG
# Duplicate image found: plantvillage dataset\color\Tomato___healthy\505465db-407b-4e0a-8110-7479dad5261c___GH_HL Leaf 389.JPG
# Duplicate image found: plantvillage dataset\color\Tomato___healthy\a5de43e7-fc2f-4a14-a8e6-c0f2f94c84f1___GH_HL Leaf 434.JPG
# Duplicate image found: plantvillage dataset\color\Tomato___healthy\cfd491d6-4af5-4728-8f0e-0d330a07174a___GH_HL Leaf 482.2.JPG
# Duplicate image found: plantvillage dataset\color\Tomato___healthy\d2ce7896-6fa4-45e6-96c5-d162da0e3e1c___GH_HL Leaf 220.JPG
# Duplicate image found: plantvillage dataset\color\Tomato___healthy\e786ac89-29fe-47e3-b49e-b9a9ee7edd9d___GH_HL Leaf 342.1.JPG
# Duplicate image found: plantvillage dataset\color\Tomato___Late_blight\2c47b891-3c97-48f1-a2cc-5aa53d3a1148___GHLB2 Leaf 9011.JPG
# Duplicate image found: plantvillage dataset\color\Tomato___Late_blight\5de6da85-f8c4-48c4-b463-3e6bd78884cc___GHLB_PS Leaf 24 Day 16.jpg
# Duplicate image found: plantvillage dataset\color\Tomato___Late_blight\bd4f09bd-ee85-4ab1-bce0-8cde3fdd7f1b___GHLB_PS Leaf 23.7 Day 13.jpg
# Duplicate image found: plantvillage dataset\color\Tomato___Late_blight\c1775bad-7c02-41fb-bb7d-f8df91d60ac3___GHLB_PS Leaf 23.5 Day 13.jpg
# Duplicate image found: plantvillage dataset\color\Tomato___Late_blight\d81682aa-746b-4e07-af2b-52ebb6f4c017___GHLB2 Leaf 102.JPG
# Duplicate image found: plantvillage dataset\color\Tomato___Late_blight\d82b634e-9a19-497b-b698-aaf100d622a1___GHLB_PS Leaf 24 Day 13.jpg
# Duplicate image found: plantvillage dataset\color\Tomato___Late_blight\e20107e7-137f-400e-817f-5dc4c58e5d70___GHLB2 Leaf 8677.JPG
# Duplicate image found: plantvillage dataset\color\Tomato___Late_blight\e5d707cd-077c-43af-bda9-6138e516ff51___GHLB2 Leaf 8999.JPG
# Class imbalance detected.

# %% [markdown]
#     Data augmentation

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

def copy_original_images(source_dir, target_dir, class_name):

    source_class_dir = os.path.join(source_dir, class_name)
    target_class_dir = os.path.join(target_dir, class_name)

    if not os.path.exists(target_class_dir):
        os.makedirs(target_class_dir)

    for filename in os.listdir(source_class_dir):
        source_path = os.path.join(source_class_dir, filename)
        target_path = os.path.join(target_class_dir, filename)
        shutil.copy2(source_path, target_path)

def augment_images(source_dir, class_name, target_dir, target_count, generator):

    source_class_dir = os.path.join(source_dir, class_name)
    target_class_dir = os.path.join(target_dir, class_name)
    
    if not os.path.exists(target_class_dir):
        os.makedirs(target_class_dir)

    current_count = len(os.listdir(source_class_dir))
    required_count = target_count - current_count
    print(f"{class_name}: There ara currently {current_count} images, and {required_count} images need to be enhanced.")

    if required_count <= 0:
        print(f"{class_name}: The target number has been reached and no enhancement is required.")
        return

    flow = generator.flow_from_directory(
        directory=source_dir,
        classes=[class_name],
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical',  
        save_to_dir=target_class_dir,
        save_prefix='aug_',
        save_format='png'
    )

    num_batches = required_count // 32 + (1 if required_count % 32 > 0 else 0)
    for i in range(num_batches):
        next(flow)
        if len(os.listdir(target_class_dir)) >= target_count:
            break

original_dataset_dir = 'A:\FinalProject\FinalProjectCode\plantvillage dataset\color'
augmented_dataset_dir = 'plantvillage dataset/augmented_dataset'
datagen = ImageDataGenerator()
data_flow = datagen.flow_from_directory(data_cleaning_path, target_size=(256, 256), class_mode='categorical')
class_indices = data_flow.class_indices
classes = list(class_indices.keys())
num_classes = len(classes)
class_counts = {}
resolutions = []

for class_name in classes:
        class_path = os.path.join(data_cleaning_path, class_name)
        class_counts[class_name] = 0

        for image_file in os.listdir(class_path):
            image_path = os.path.join(class_path, image_file)
            try:
                with Image.open(image_path) as img:
                    resolutions.append(img.size) 
                    class_counts[class_name] += 1
            except IOError:
                print(f"Cannot open image: {image_path}")
resolutions = np.array(resolutions)
unique_resolutions, counts = np.unique(resolutions, axis=0, return_counts=True)
most_common_resolution = unique_resolutions[np.argmax(counts)]

print("Class labels:")
for class_name, label in class_indices.items():
    copy_original_images(original_dataset_dir, augmented_dataset_dir, class_name)

for class_name, label in class_indices.items():
    augment_images(original_dataset_dir, class_name, augmented_dataset_dir, 5000, datagen)

print("Done!")
# Out:
# Found 54305 images belonging to 38 classes.
# Class labels:
# Apple___Apple_scab: There ara currently 630 images, and 4370 images need to be enhanced.
# Found 630 images belonging to 1 classes.
# Apple___Black_rot: There ara currently 621 images, and 4379 images need to be enhanced.
# Found 621 images belonging to 1 classes.
# Apple___Cedar_apple_rust: There ara currently 275 images, and 4725 images need to be enhanced.
# Found 275 images belonging to 1 classes.
# Apple___healthy: There ara currently 1645 images, and 3355 images need to be enhanced.
# Found 1645 images belonging to 1 classes.
# Blueberry___healthy: There ara currently 1502 images, and 3498 images need to be enhanced.
# Found 1502 images belonging to 1 classes.
# Cherry_(including_sour)___Powdery_mildew: There ara currently 1052 images, and 3948 images need to be enhanced.
# Found 1052 images belonging to 1 classes.
# Cherry_(including_sour)___healthy: There ara currently 854 images, and 4146 images need to be enhanced.
# Found 854 images belonging to 1 classes.
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: There ara currently 513 images, and 4487 images need to be enhanced.
# Found 513 images belonging to 1 classes.
# Corn_(maize)___Common_rust_: There ara currently 1192 images, and 3808 images need to be enhanced.
# Found 1192 images belonging to 1 classes.
# Corn_(maize)___Northern_Leaf_Blight: There ara currently 985 images, and 4015 images need to be enhanced.
# Found 985 images belonging to 1 classes.
# Corn_(maize)___healthy: There ara currently 1162 images, and 3838 images need to be enhanced.
# Found 1162 images belonging to 1 classes.
# Grape___Black_rot: There ara currently 1180 images, and 3820 images need to be enhanced.
# Found 1180 images belonging to 1 classes.
# Grape___Esca_(Black_Measles): There ara currently 1383 images, and 3617 images need to be enhanced.
# Found 1383 images belonging to 1 classes.
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot): There ara currently 1076 images, and 3924 images need to be enhanced.
# Found 1076 images belonging to 1 classes.
# Grape___healthy: There ara currently 423 images, and 4577 images need to be enhanced.
# Found 423 images belonging to 1 classes.
# Orange___Haunglongbing_(Citrus_greening): There ara currently 5507 images, and -507 images need to be enhanced.
# Orange___Haunglongbing_(Citrus_greening): The target number has been reached and no enhancement is required.
# Peach___Bacterial_spot: There ara currently 2297 images, and 2703 images need to be enhanced.
# Found 2297 images belonging to 1 classes.
# Peach___healthy: There ara currently 360 images, and 4640 images need to be enhanced.
# Found 360 images belonging to 1 classes.
# Pepper,_bell___Bacterial_spot: There ara currently 997 images, and 4003 images need to be enhanced.
# Found 997 images belonging to 1 classes.
# Pepper,_bell___healthy: There ara currently 1478 images, and 3522 images need to be enhanced.
# Found 1478 images belonging to 1 classes.
# Potato___Early_blight: There ara currently 1000 images, and 4000 images need to be enhanced.
# Found 1000 images belonging to 1 classes.
# Potato___Late_blight: There ara currently 1000 images, and 4000 images need to be enhanced.
# Found 1000 images belonging to 1 classes.
# Potato___healthy: There ara currently 152 images, and 4848 images need to be enhanced.
# Found 152 images belonging to 1 classes.
# Raspberry___healthy: There ara currently 371 images, and 4629 images need to be enhanced.
# Found 371 images belonging to 1 classes.
# Soybean___healthy: There ara currently 5090 images, and -90 images need to be enhanced.
# Soybean___healthy: The target number has been reached and no enhancement is required.
# Squash___Powdery_mildew: There ara currently 1835 images, and 3165 images need to be enhanced.
# Found 1835 images belonging to 1 classes.
# Strawberry___Leaf_scorch: There ara currently 1109 images, and 3891 images need to be enhanced.
# Found 1109 images belonging to 1 classes.
# Strawberry___healthy: There ara currently 456 images, and 4544 images need to be enhanced.
# Found 456 images belonging to 1 classes.
# Tomato___Bacterial_spot: There ara currently 2127 images, and 2873 images need to be enhanced.
# Found 2127 images belonging to 1 classes.
# Tomato___Early_blight: There ara currently 1000 images, and 4000 images need to be enhanced.
# Found 1000 images belonging to 1 classes.
# Tomato___Late_blight: There ara currently 1909 images, and 3091 images need to be enhanced.
# Found 1909 images belonging to 1 classes.
# Tomato___Leaf_Mold: There ara currently 952 images, and 4048 images need to be enhanced.
# Found 952 images belonging to 1 classes.
# Tomato___Septoria_leaf_spot: There ara currently 1771 images, and 3229 images need to be enhanced.
# Found 1771 images belonging to 1 classes.
# Tomato___Spider_mites Two-spotted_spider_mite: There ara currently 1676 images, and 3324 images need to be enhanced.
# Found 1676 images belonging to 1 classes.
# Tomato___Target_Spot: There ara currently 1404 images, and 3596 images need to be enhanced.
# Found 1404 images belonging to 1 classes.
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: There ara currently 5357 images, and -357 images need to be enhanced.
# Tomato___Tomato_Yellow_Leaf_Curl_Virus: The target number has been reached and no enhancement is required.
# Tomato___Tomato_mosaic_virus: There ara currently 373 images, and 4627 images need to be enhanced.
# Found 373 images belonging to 1 classes.
# Tomato___healthy: There ara currently 1591 images, and 3409 images need to be enhanced.
# Found 1591 images belonging to 1 classes.
# Done!

# %%
data_dir = 'A:\FinalProject\FinalProjectCode\plantvillage dataset/augmented_dataset'  

def display_sample_images_with_info_after_augmentation(directory, num_images=5):
    images = []
    labels = []

    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if not os.path.isdir(class_path):
            continue

        image_files = os.listdir(class_path)
        images += [os.path.join(class_path, file) for file in image_files]
        labels += [class_name for _ in image_files]

    selected_indices = random.sample(range(len(images)), num_images)
    sample_images = [images[i] for i in selected_indices]
    sample_labels = [labels[i] for i in selected_indices]

    plt.figure(figsize=(20, 3))
    for i, image_path in enumerate(sample_images):
        img = Image.open(image_path)
        plt.subplot(1, num_images, i+1)
        plt.imshow(img)
        plt.title(os.path.basename(image_path)+'\n'+f'{sample_labels[i]}\n{img.size}')
        plt.axis('off')
    
    plt.show()
display_sample_images_with_info_after_augmentation(data_dir)

# %% [markdown]
#     Data Split

# %%
def split_dataset(original_dir, target_dir, train_ratio=0.8, val_ratio=0.1):
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
        os.makedirs(os.path.join(target_dir, 'train'))
        os.makedirs(os.path.join(target_dir, 'validation'))
        os.makedirs(os.path.join(target_dir, 'test'))

    classes = [d for d in os.listdir(original_dir) if os.path.isdir(os.path.join(original_dir, d))]

    for cls in classes:
        os.makedirs(os.path.join(target_dir, 'train', cls))
        os.makedirs(os.path.join(target_dir, 'validation', cls))
        os.makedirs(os.path.join(target_dir, 'test', cls))

        all_images = os.listdir(os.path.join(original_dir, cls))
        np.random.shuffle(all_images)

        train_end = int(len(all_images) * train_ratio)
        val_end = train_end + int(len(all_images) * val_ratio)

        for i, img in enumerate(all_images):
            if i < train_end:
                subset = 'train'
            elif i < val_end:
                subset = 'validation'
            else:
                subset = 'test'

            src = os.path.join(original_dir, cls, img)
            dst = os.path.join(target_dir, subset, cls, img)
            shutil.copy(src, dst)

def count_images_in_subfolders(directory):
    counts = {}
    for subset in ['train', 'validation', 'test']:
        subset_path = os.path.join(directory, subset)
        for cls in os.listdir(subset_path):
            class_path = os.path.join(subset_path, cls)
            if os.path.isdir(class_path):
                count = len(os.listdir(class_path))
                counts[f"{subset}/{cls}"] = count
    return counts


augmented_dataset_dir = "A:\FinalProject\FinalProjectCode\plantvillage dataset/augmented_dataset"
splited_dataset_dir = "A:\FinalProject\FinalProjectCode\plantvillage dataset/splited_dataset"

split_dataset(augmented_dataset_dir, splited_dataset_dir)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

def visualize_data_splits(train_dir, validation_dir, test_dir):
    categories = set()
    data = {'train': {}, 'validation': {}, 'test': {}}

    # Gathering data
    for dataset, directory in zip(['train', 'validation', 'test'], [train_dir, validation_dir, test_dir]):
        for category in os.listdir(directory):
            category_path = os.path.join(directory, category)
            if os.path.isdir(category_path):
                categories.add(category)
                data[dataset][category] = len(os.listdir(category_path))

    # Sorting categories
    categories = sorted(list(categories))
    
    # Setting up the bar width and positions
    bar_width = 0.3
    r1 = np.arange(len(categories))
    r2 = [x + bar_width for x in r1]
    r3 = [x + bar_width for x in r2]

    # Creating the bar chart with adjusted figure size for a vertical layout
    plt.figure(figsize=(40, 15))
    
    # Creating bars with bolder edge
    plt.bar(r1, [data['train'].get(category, 0) for category in categories], color='#ADD8E6', width=bar_width, edgecolor='grey', linewidth=3, label='Train')
    plt.bar(r2, [data['validation'].get(category, 0) for category in categories], color='#FFC0CB', width=bar_width, edgecolor='grey', linewidth=3, label='Validation')
    plt.bar(r3, [data['test'].get(category, 0) for category in categories], color='#90EE90', width=bar_width, edgecolor='grey', linewidth=3, label='Test')

    # Adding labels and titles with larger font sizes
    plt.xlabel('Categories', fontweight='bold', fontsize=20)
    plt.ylabel('Number of Images', fontweight='bold', fontsize=20)
    plt.xticks([r + bar_width for r in range(len(categories))], categories, rotation=90, fontsize=16)
    plt.yticks(fontsize=16)
    plt.legend(fontsize=16)

    # Function to add value labels
    def add_labels(r, dataset):
        for i in range(len(categories)):
            plt.text(x=r[i], y=data[dataset][categories[i]] + 10, 
                    s=data[dataset][categories[i]], ha='center', 
                    fontsize=14, fontweight= "bold",rotation=90)  # Rotate text to vertical

    # Adding labels to bars
    add_labels(r1, 'train')
    add_labels(r2, 'validation')
    add_labels(r3, 'test')

    # Display the figure
    plt.show()

# %%
splited_dataset_dir = "A:\FinalProject\FinalProjectCode\plantvillage dataset/splited_dataset"
train_dir = os.path.join(splited_dataset_dir, 'train')
validation_dir = os.path.join(splited_dataset_dir, 'validation')
test_dir = os.path.join(splited_dataset_dir, 'test')
visualize_data_splits(train_dir, validation_dir, test_dir)

# %%
def count_images_in_subfolders(directory):
    counts = {}
    for subset in ['train', 'validation', 'test']:
        subset_path = os.path.join(directory, subset)
        for cls in os.listdir(subset_path):
            class_path = os.path.join(subset_path, cls)
            if os.path.isdir(class_path):
                count = len(os.listdir(class_path))
                counts[f"{subset}/{cls}"] = count
    return counts

counts = count_images_in_subfolders(splited_dataset_dir)
for key, count in counts.items():
    print(f"{key}: {count} images")

def visualize_data_splits(train_dir, validation_dir, test_dir):
    categories = set()
    data = {'train': {}, 'validation': {}, 'test': {}}

    for dataset, directory in zip(['train', 'validation', 'test'], [train_dir, validation_dir, test_dir]):
        for category in os.listdir(directory):
            category_path = os.path.join(directory, category)
            if os.path.isdir(category_path):
                categories.add(category)
                data[dataset][category] = len(os.listdir(category_path))

    categories = sorted(list(categories))
    
    bar_width = 0.2
    r1 = np.arange(len(categories))
    r2 = [x + bar_width for x in r1]
    r3 = [x + bar_width for x in r2]
    plt.figure(figsize=(10, 5))
    plt.bar(r1, [data['train'].get(category, 0) for category in categories], color='#ADD8E6', width=bar_width, edgecolor='grey', label='Train')
    plt.bar(r2, [data['validation'].get(category, 0) for category in categories], color='#FFC0CB', width=bar_width, edgecolor='grey', label='Validation')
    plt.bar(r3, [data['test'].get(category, 0) for category in categories], color='#90EE90', width=bar_width, edgecolor='grey', label='Test')

    plt.xlabel('Categories', fontweight='bold', fontsize=14)
    plt.ylabel('Number of Images', fontweight='bold', fontsize=14)
    plt.xticks([r + bar_width for r in range(len(categories))], categories, rotation=45, fontsize=12)
    plt.legend(fontsize=12)
    

    def add_labels(r, dataset):
        for i in range(len(categories)):
            plt.text(x=r[i], y=data[dataset][categories[i]] + 5, s=data[dataset][categories[i]], ha='center', fontsize=10)


    add_labels(r1, 'train')
    add_labels(r2, 'validation')
    add_labels(r3, 'test')

    plt.show()

splited_dataset_dir = "A:\FinalProject\FinalProjectCode\plantvillage dataset/splited_dataset"
train_dir = os.path.join(splited_dataset_dir, 'train')
validation_dir = os.path.join(splited_dataset_dir, 'validation')
test_dir = os.path.join(splited_dataset_dir, 'test')

visualize_data_splits(train_dir, validation_dir, test_dir)
# Out:
# train/Apple___Apple_scab: 3963 images
# train/Apple___Black_rot: 3912 images
# train/Apple___Cedar_apple_rust: 3842 images
# train/Apple___healthy: 3973 images
# train/Blueberry___healthy: 4014 images
# train/Cherry_(including_sour)___healthy: 3979 images
# train/Cherry_(including_sour)___Powdery_mildew: 4006 images
# train/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 3821 images
# train/Corn_(maize)___Common_rust_: 3942 images
# train/Corn_(maize)___healthy: 3948 images
# train/Corn_(maize)___Northern_Leaf_Blight: 3991 images
# train/Grape___Black_rot: 4006 images
# train/Grape___Esca_(Black_Measles): 3984 images
# train/Grape___healthy: 3824 images
# train/Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 3980 images
# train/Orange___Haunglongbing_(Citrus_greening): 4405 images
# train/Peach___Bacterial_spot: 4008 images
# train/Peach___healthy: 3769 images
# train/Pepper,_bell___Bacterial_spot: 3958 images
# train/Pepper,_bell___healthy: 3982 images
# train/Potato___Early_blight: 3942 images
# train/Potato___healthy: 3820 images
# train/Potato___Late_blight: 3942 images
# train/Raspberry___healthy: 3884 images
# train/Soybean___healthy: 4072 images
# train/Squash___Powdery_mildew: 3985 images
# train/Strawberry___healthy: 3827 images
# train/Strawberry___Leaf_scorch: 3984 images
# train/Tomato___Bacterial_spot: 3992 images
# train/Tomato___Early_blight: 3942 images
# train/Tomato___healthy: 3997 images
# train/Tomato___Late_blight: 4001 images
# train/Tomato___Leaf_Mold: 3987 images
# train/Tomato___Septoria_leaf_spot: 3985 images
# train/Tomato___Spider_mites Two-spotted_spider_mite: 3987 images
# train/Tomato___Target_Spot: 4009 images
# train/Tomato___Tomato_mosaic_virus: 3904 images
# train/Tomato___Tomato_Yellow_Leaf_Curl_Virus: 4285 images
# validation/Apple___Apple_scab: 495 images
# validation/Apple___Black_rot: 489 images
# validation/Apple___Cedar_apple_rust: 480 images
# validation/Apple___healthy: 496 images
# validation/Blueberry___healthy: 501 images
# validation/Cherry_(including_sour)___healthy: 497 images
# validation/Cherry_(including_sour)___Powdery_mildew: 500 images
# validation/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 477 images
# validation/Corn_(maize)___Common_rust_: 492 images
# validation/Corn_(maize)___healthy: 493 images
# validation/Corn_(maize)___Northern_Leaf_Blight: 498 images
# validation/Grape___Black_rot: 500 images
# validation/Grape___Esca_(Black_Measles): 498 images
# validation/Grape___healthy: 478 images
# validation/Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 497 images
# validation/Orange___Haunglongbing_(Citrus_greening): 550 images
# validation/Peach___Bacterial_spot: 501 images
# validation/Peach___healthy: 471 images
# validation/Pepper,_bell___Bacterial_spot: 494 images
# validation/Pepper,_bell___healthy: 497 images
# validation/Potato___Early_blight: 492 images
# validation/Potato___healthy: 477 images
# validation/Potato___Late_blight: 492 images
# validation/Raspberry___healthy: 485 images
# validation/Soybean___healthy: 509 images
# validation/Squash___Powdery_mildew: 498 images
# validation/Strawberry___healthy: 478 images
# validation/Strawberry___Leaf_scorch: 498 images
# validation/Tomato___Bacterial_spot: 499 images
# validation/Tomato___Early_blight: 492 images
# validation/Tomato___healthy: 499 images
# validation/Tomato___Late_blight: 500 images
# validation/Tomato___Leaf_Mold: 498 images
# validation/Tomato___Septoria_leaf_spot: 498 images
# validation/Tomato___Spider_mites Two-spotted_spider_mite: 498 images
# validation/Tomato___Target_Spot: 501 images
# validation/Tomato___Tomato_mosaic_virus: 488 images
# validation/Tomato___Tomato_Yellow_Leaf_Curl_Virus: 535 images
# test/Apple___Apple_scab: 496 images
# test/Apple___Black_rot: 490 images
# test/Apple___Cedar_apple_rust: 481 images
# test/Apple___healthy: 498 images
# test/Blueberry___healthy: 503 images
# test/Cherry_(including_sour)___healthy: 498 images
# test/Cherry_(including_sour)___Powdery_mildew: 502 images
# test/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 479 images
# test/Corn_(maize)___Common_rust_: 494 images
# test/Corn_(maize)___healthy: 495 images
# test/Corn_(maize)___Northern_Leaf_Blight: 500 images
# test/Grape___Black_rot: 502 images
# test/Grape___Esca_(Black_Measles): 499 images
# test/Grape___healthy: 479 images
# test/Grape___Leaf_blight_(Isariopsis_Leaf_Spot): 499 images
# test/Orange___Haunglongbing_(Citrus_greening): 552 images
# test/Peach___Bacterial_spot: 501 images
# test/Peach___healthy: 472 images
# test/Pepper,_bell___Bacterial_spot: 496 images
# test/Pepper,_bell___healthy: 499 images
# test/Potato___Early_blight: 494 images
# test/Potato___healthy: 479 images
# test/Potato___Late_blight: 494 images
# test/Raspberry___healthy: 486 images
# test/Soybean___healthy: 509 images
# test/Squash___Powdery_mildew: 499 images
# test/Strawberry___healthy: 479 images
# test/Strawberry___Leaf_scorch: 498 images
# test/Tomato___Bacterial_spot: 499 images
# test/Tomato___Early_blight: 494 images
# test/Tomato___healthy: 501 images
# test/Tomato___Late_blight: 501 images
# test/Tomato___Leaf_Mold: 499 images
# test/Tomato___Septoria_leaf_spot: 499 images
# test/Tomato___Spider_mites Two-spotted_spider_mite: 499 images
# test/Tomato___Target_Spot: 502 images
# test/Tomato___Tomato_mosaic_virus: 489 images
# test/Tomato___Tomato_Yellow_Leaf_Curl_Virus: 537 images
